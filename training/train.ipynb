# %%
# !pip install -qqq rfdetr supervision roboflow
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlx-lm 0.30.7 requires transformers>=5.0.0, but you have transformers 4.57.6 which is incompatible.
# mlx-vlm 0.3.12 requires transformers>=5.1.0, but you have transformers 4.57.6 which is incompatible.
# sphinx 9.1.0 requires docutils<0.23,>=0.21, but you have docutils 0.19 which is incompatible.

# %%
from rfdetr import RFDETRNano
import supervision as sv 
import numpy as np 
import matplotlib.pyplot as plt 
import cv2 
import os 
from pathlib import Path 

model = RFDETRNano()
# Out:
# [2026-03-07 21:56:36] [INFO] rf-detr - Downloading pretrained weights for rf-detr-nano.pth
# rf-detr-nano.pth:   0%|          | 0.00/349M [00:00<?, ?iB/s]
# [2026-03-07 21:56:45] [INFO] rf-detr - MD5 validation successful for rf-detr-nano.pth
# [2026-03-07 21:56:45] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-03-07 21:56:45] [WARNING] rf-detr - Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-03-07 21:56:46] [INFO] rf-detr - Loading pretrain weights
